# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from math import factorial

# %%
A=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/EX12-1/advection_00050.d')
B=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/EX12-1/advection_00100.d')
C=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/EX12-1/advection_00150.d')
D=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/EX12-1/advection_00250.d')


plt.plot(A[:,1],A[:,2],'r',label='50') 
plt.plot(B[:,1],B[:,2],'b',label='100') 
plt.plot(C[:,1],C[:,2],'g',label='150')
plt.plot(D[:,1],D[:,2],'y',label='250')
plt.xlabel('x')
plt.ylabel('y')
#plt.rcParams['figure.figsize'] = [15,5]
plt.legend()
plt.title('PLM')
plt.savefig('EX.png')
plt.show()
