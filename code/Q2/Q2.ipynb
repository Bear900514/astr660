# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from math import factorial

# %%
A=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/HW4/Q2/binary_001.dat')
B=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/HW4/Q2/binary_002.dat')

# %%
plt.plot(A[:,7],A[:,8],'b',label='m1') 
#plt.plot(B[:,3],B[:,4],'r',label='m2')

# %%
plt.plot(A[:,3],A[:,4],'b',label='m1') 
plt.plot(B[:,3],B[:,4],'r',label='m2')
plt.xlabel('x')
plt.ylabel('y')
#plt.rcParams['figure.figsize'] = [15,5]
plt.legend()
plt.title('x-y with dt=0.00001')
plt.savefig('Q2-1.1.png')
plt.show()

# %%
A=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/HW4/Q2/binary_001_0.01.dat')
B=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/HW4/Q2/binary_002_0.01.dat')
plt.plot(A[:,3],A[:,4],'b',label='m1') 
plt.plot(B[:,3],B[:,4],'r',label='m2')
plt.xlabel('x')
plt.ylabel('y')
#plt.rcParams['figure.figsize'] = [15,5]
plt.legend()
plt.title('x-y with dt=0.01')
plt.savefig('Q2-1.2.png')
plt.show()
