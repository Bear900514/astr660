# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from math import factorial

# %%
A=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/EX11-17/advection_00000.d')
b=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/EX11-17/advection_000001.d')
plt.subplot(121)
plt.plot(b[:,1],b[:,2],'b',label='FTCS') 
plt.xlabel('x')
plt.ylabel('U (x)')
plt.title('U (x) V.S. x in FTCS method')
plt.subplot(122)
plt.plot(A[:,1],A[:,2],'r',label='upwind') 
plt.rcParams['figure.figsize'] = [15,5]
plt.xlabel('x')
plt.ylabel('U (x)')
plt.title('U (x) V.S. x in upwimd method')
plt.savefig('method.png')

# %%
A=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/EX11-17/advection_00130.d')
b=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/EX11-17/advection_000001.d')
plt.subplot(121)
plt.plot(b[:,1],b[:,2],'b',label='FTCS') 
plt.xlabel('x')
plt.ylabel('U (x)')
plt.title('U (x) V.S. x in FTCS method')
plt.subplot(122)
plt.plot(A[:,1],A[:,2],'r',label='upwind') 
plt.rcParams['figure.figsize'] = [15,5]
plt.xlabel('x')
plt.ylabel('U (x)')
plt.title('U (x) V.S. x in FTCS method with 1.2CFL number')
plt.savefig('CFL.png')
