# %%
from mpl_toolkits.mplot3d import axes3d
import numpy as np
import matplotlib.pyplot as plt
import math
from math import factorial

# %%
A=np.loadtxt('C:/Users/Bear/OneDrive/文件/程式/HW5/Q3/advection_00800.d')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
#ax.plot_surface(A[:,1], A[:,2], A[:,3], cmap='seismic')
#ax.plot_wireframe(A[:,1], A[:,2], A[:,3], rstride=10, cstride=10)
ax.scatter(A[:,1], A[:,2], A[:,3], c=A[:,3], cmap='Reds', marker='^', label='My Points 1')
plt.savefig('Q2-1.1.png')
plt.show()
